# %%
import numpy as np
import pandas as pd

# %%
census_data = pd.read_csv("census_data_school_shootings.csv")

# %%
census_data.head()
# Out:
#    Zipcode  Population  Household Income  Poverty Count  Poverty Rate  \
# 0      601     18450.0           12041.0        10816.0     58.623306
# 1      602     41302.0           15663.0        22409.0     54.256452
# 2      603     53683.0           15485.0        26220.0     48.842278
# 3      606      6591.0           15019.0         3721.0     56.455773
# 4      610     28963.0           16707.0        14569.0     50.302110
#
#    Unemployment Count  Unemployment Rate
# 0              1464.0           7.934959
# 1              4767.0          11.541814
# 2              4341.0           8.086359
# 3               134.0           2.033075
# 4              1134.0           3.915340

# %%
# Set new index to ZipCode
census_data = census_data.set_index("Zipcode")
census_data.head(10)
# Out:
#          Population  Household Income  Poverty Count  Poverty Rate  \
# Zipcode
# 601         18450.0           12041.0        10816.0     58.623306
# 602         41302.0           15663.0        22409.0     54.256452
# 603         53683.0           15485.0        26220.0     48.842278
# 606          6591.0           15019.0         3721.0     56.455773
# 610         28963.0           16707.0        14569.0     50.302110
# 612         68055.0           17848.0        30695.0     45.103225
# 616         10183.0           15342.0         4808.0     47.215948
# 617         24879.0           14982.0        13362.0     53.707946
# 622          6165.0           14281.0         3700.0     60.016221
# 623         44704.0           17389.0        21322.0     47.695956
#
#          Unemployment Count  Unemployment Rate
# Zipcode
# 601                  1464.0           7.934959
# 602                  4767.0          11.541814
# 603                  4341.0           8.086359
# ...

# %%
school_shootings = census_data.loc[[77517, 80123]]
school_shootings
# Out:
#          Population  Household Income  Poverty Count  Poverty Rate  \
# Zipcode
# 77517        6235.0           83472.0          825.0     13.231756
# 80123       44102.0           72508.0         2321.0      5.262800
#
#          Unemployment Count  Unemployment Rate
# Zipcode
# 77517                 207.0           3.319968
# 80123                1647.0           3.734525
